# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
airlines=pd.read_excel("EastWestAirlines.xlsx",sheet_name='data')
airlines.tail()
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 3994       1
# 3995       1
# 3996       1
# ...

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines.drop(["ID#"],axis=1,inplace=True)

# %%
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airlines[airlines.duplicated()]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3876     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3876            0                  0                0               1597
#
#       Award?
# 3876       0

# %%
airlines1=airlines.drop_duplicates()

# %%
airlines1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3998 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3998 non-null   int64
#  1   Qual_miles         3998 non-null   int64
#  2   cc1_miles          3998 non-null   int64
#  3   cc2_miles          3998 non-null   int64
#  4   cc3_miles          3998 non-null   int64
#  5   Bonus_miles        3998 non-null   int64
#  6   Bonus_trans        3998 non-null   int64
#  7   Flight_miles_12mo  3998 non-null   int64
#  8   Flight_trans_12    3998 non-null   int64
#  9   Days_since_enroll  3998 non-null   int64
#  10  Award?             3998 non-null   int64
# dtypes: int64(11)
# memory usage: 374.8 KB

# %%
#normalization of the data

def norm_func(i):
    x=(i-i.min())/(i.max()-i.min())
    return (x)

# %%
#selection all the columns and rows from the airlines_norm
airlines_norm=norm_func(airlines1.iloc[:,:])
airlines_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # agglomerative clustering

# %%
#creating dendogram for normalized data
plt.figure(figsize=(17,14))
dendrogram= sch.dendrogram(sch.linkage(airlines_norm, method='complete'))

# %%
#creating clusters 
hc=AgglomerativeClustering(n_clusters=6,affinity='euclidean',linkage='complete')
hc
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=6)

# %%
pred_hc=hc.fit_predict(airlines_norm)
pred_hc
# Out:
# array([2, 2, 2, ..., 0, 2, 2], dtype=int64)

# %%
#inserting clusters into original data set 
airlines1['aggl_clust']= pred_hc
airlines1
# Out:
# C:\Users\91840\AppData\Local\Temp/ipykernel_15828/131687997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airlines1['aggl_clust']= pred_hc
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# ...

# %%
#groupby by agglomerative clustering in which 6 clusters are considered
airlines1.iloc[:,:].groupby(airlines1.aggl_clust).mean()
# Out:
#                   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# aggl_clust
# 0            80173.963287  248.550699   2.104895   1.009615   1.000874
# 1           157084.578462  208.673846   4.661538   1.000000   1.061538
# 2            59984.802410   88.587550   1.713253   1.000402   1.006024
# 3           131999.500000  347.000000   2.500000   1.000000   1.000000
# 4            45515.064516   32.258065   1.000000   2.483871   1.000000
# 5            64521.000000  295.500000   1.250000   1.000000   4.250000
#
#              Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# aggl_clust
# 0           16882.864510    13.412587         739.958916         2.236888
# 1           70477.086154    23.249231        1019.433846         3.196923
# 2           10174.446988     9.098795         227.330924         0.653815
# 3           65634.250000    69.250000       19960.000000        49.250000
# ...

# %% [markdown]
# # k means clustering

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(airlines_norm)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#from the above elbow curve we can select 4 clusters
model=KMeans(n_clusters=4)
model.fit(airlines_norm)
# Out:
# KMeans(n_clusters=4)

# %%
model.labels_
# Out:
# array([1, 1, 1, ..., 2, 1, 1])

# %%
labels=pd.Series(model.labels_)
airlines1['kmeans_clust']=labels
airlines1
# Out:
# C:\Users\91840\AppData\Local\Temp/ipykernel_15828/566708467.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airlines1['kmeans_clust']=labels
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# ...

# %%
airlines1.iloc[:,0:11].groupby(airlines1.kmeans_clust).mean()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# kmeans_clust
# 0.0            83560.881129  287.869242   1.160475   1.032689   1.008915
# 1.0            41170.790084   94.479958   1.114979   1.017932   1.004219
# 2.0           108018.054523  195.837670   3.890954   1.001239   1.026022
# 3.0           117328.231884   73.112721   3.541063   1.001610   1.022544
#
#                Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# kmeans_clust
# 0.0            8843.659733    10.450223        1022.702823         3.132244
# 1.0            3658.878692     6.647152         231.829641         0.666139
# 2.0           45185.348203    20.089219         715.789343         2.147460
# 3.0           30931.798712    16.985507         216.252818         0.626409
#
#               Days_since_enroll    Award?
# kmeans_clust
# 0.0                 4338.890045  0.974740
# 1.0                 3620.287447  0.011076
# 2.0                 4867.275093  0.992565
# ...

# %% [markdown]
# # DB SCAN

# %%
from sklearn.cluster import DBSCAN

# %%
airlines_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
dbscan=DBSCAN(eps=0.5, min_samples=10)
dbscan.fit(airlines_norm)
# Out:
# DBSCAN(min_samples=10)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
labels=pd.Series(dbscan.labels_)
airlines['dbclust']=labels
airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...
